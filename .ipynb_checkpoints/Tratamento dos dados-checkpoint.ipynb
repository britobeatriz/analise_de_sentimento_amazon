# %% [markdown]
# # Visualização dos dados e tratamento

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## Visualizando e conhecendo o DataFrame

# %%
dados = pd.read_csv('dados/scrap.csv', sep=';')
dados.head(20)
# Out:
#             avaliacao                                              texto
# 0   1,0 de 5 estrelas            \nO livro chegou bastante 'entortado'\n
# 1   5,0 de 5 estrelas  \nO livro de Dale Carnegie é um clássico da au...
# 2   5,0 de 5 estrelas  \nConfesso que sempre tenho um preconceito com...
# 3   5,0 de 5 estrelas  \nJá tinha lido outro livro do Dale Carnegie a...
# 4   5,0 de 5 estrelas  \nClássico atemporal publicado pela primeira v...
# 5   1,0 de 5 estrelas  \nO livro atribui boas estratégias, mas identi...
# 6   3,0 de 5 estrelas  \nTem algumas lições interessantes. Mas virou ...
# 7   5,0 de 5 estrelas  \nVi uma uma recomendação do Buffet, que disse...
# 8   5,0 de 5 estrelas  \nO livro chegou em ótimo estado ( como era de...
# 9   5,0 de 5 estrelas  \nO conteúdo desse livro nos gera uma reavalia...
# 10  1,0 de 5 estrelas            \nO livro chegou bastante 'entortado'\n
# 11  5,0 de 5 estrelas  \nO livro de Dale Carnegie é um clássico da au...
# 12  5,0 de 5 estrelas  \nConfesso que sempre tenho um preconceito com...
# 13  5,0 de 5 estrelas  \nJá tinha lido outro livro do Dale Carnegie a...
# 14  5,0 de 5 estrelas  \nClássico atemporal publicado pela primeira v...
# 15  1,0 de 5 estrelas  \nO livro atribui boas estratégias, mas identi...
# 16  3,0 de 5 estrelas  \nTem algumas lições interessantes. Mas virou ...
# 17  5,0 de 5 estrelas  \nVi uma uma recomendação do Buffet, que disse...
# 18  5,0 de 5 estrelas  \nO livro chegou em ótimo estado ( como era de...
# 19  5,0 de 5 estrelas  \nO conteúdo desse livro nos gera uma reavalia...

# %%
print(f'O DataFrame possui {dados.shape[0]} linhas e {dados.shape[1]} colunas.')
# Out:
# O DataFrame possui 450 linhas e 2 colunas.

# %%
print('Ocorrencia de valor nulo em cada coluna:')
dados.isna().sum()
# Out:
# Ocorrencia de valor nulo em cada coluna:
# avaliacao    0
# texto        0
# dtype: int64

# %%
# transformando dados #

# removendo o \n da coluna 'texto' #
dados['texto'] = dados['texto'].map(lambda x: str(x).replace('\n', ''))

# removendo "de 5 estrelas" dos valores da coluna 'avaliacao' #
dados['avaliacao'] = dados['avaliacao'].map(lambda x: str(x).replace(',0 de 5 estrelas', '',))

# transformando 'avaliacao' em numeros inteiros #
dados['avaliacao'] = dados['avaliacao'].astype(int)

# adicionando coluna 'sentimento' #
df = pd.DataFrame(dados,columns=['avaliacao','texto','sentimento'])

# substuindo valores nulos por sentimentos #
#(<3) = insatisfação, (3) = neutro, (>3) = satisfação
df.loc[df.avaliacao < 3,'sentimento']='insatisfação'
df.loc[df.avaliacao == 3,'sentimento']='neutro'
df.loc[df.avaliacao > 3,'sentimento']='satisfação'
#  #  #  #

# %%
df.head(20)
# Out:
#     avaliacao                                              texto    sentimento
# 0           1                O livro chegou bastante 'entortado'  insatisfação
# 1           5  O livro de Dale Carnegie é um clássico da auto...    satisfação
# 2           5  Confesso que sempre tenho um preconceito com l...    satisfação
# 3           5  Já tinha lido outro livro do Dale Carnegie ant...    satisfação
# 4           5  Clássico atemporal publicado pela primeira vez...    satisfação
# 5           1  O livro atribui boas estratégias, mas identifi...  insatisfação
# 6           3  Tem algumas lições interessantes. Mas virou um...        neutro
# 7           5  Vi uma uma recomendação do Buffet, que disse q...    satisfação
# 8           5  O livro chegou em ótimo estado ( como era de s...    satisfação
# 9           5  O conteúdo desse livro nos gera uma reavaliaçã...    satisfação
# 10          1                O livro chegou bastante 'entortado'  insatisfação
# 11          5  O livro de Dale Carnegie é um clássico da auto...    satisfação
# 12          5  Confesso que sempre tenho um preconceito com l...    satisfação
# 13          5  Já tinha lido outro livro do Dale Carnegie ant...    satisfação
# 14          5  Clássico atemporal publicado pela primeira vez...    satisfação
# 15          1  O livro atribui boas estratégias, mas identifi...  insatisfação
# 16          3  Tem algumas lições interessantes. Mas virou um...        neutro
# 17          5  Vi uma uma recomendação do Buffet, que disse q...    satisfação
# 18          5  O livro chegou em ótimo estado ( como era de s...    satisfação
# 19          5  O conteúdo desse livro nos gera uma reavaliaçã...    satisfação
